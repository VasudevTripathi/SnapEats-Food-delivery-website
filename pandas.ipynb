# %% [markdown]
# <a href="https://colab.research.google.com/github/VasudevTripathi/SnapEats-Food-delivery-website/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##*Shift Enter se code run hota hai likhne ke baad*

# %%
import pandas as pd

# %%
df = pd.read_csv("sample.csv")

# %%
df
# Out:
#   name  age  english  maths  computer
# 0    A   23       90     85        25
# 1    B   22       98     41        14
# 2    C   21       85     45        78
# 3    D   21       43     62        12
# 4    E   22       23     12         0
# 5    F   20       65      0        45
# 6    G   20       45     47        87

# %% [markdown]
# #**Top5 rows show kar deta hai head()**

# %%
df.head()
# Out:
#   name  age  english  maths  computer
# 0    A   23       90     85        25
# 1    B   22       98     41        14
# 2    C   21       85     45        78
# 3    D   21       43     62        12
# 4    E   22       23     12         0

# %% [markdown]
# ##**Bottom 5 rows show karta hai tail()**

# %%
df.tail()
# Out:
#   name  age  english  maths  computer
# 2    C   21       85     45        78
# 3    D   21       43     62        12
# 4    E   22       23     12         0
# 5    F   20       65      0        45
# 6    G   20       45     47        87

# %%
df.columns
# Out:
# Index(['name', 'age', 'english', 'maths', 'computer'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7 non-null      object
#  1   age       7 non-null      int64
#  2   english   7 non-null      int64
#  3   maths     7 non-null      int64
#  4   computer  7 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 408.0+ bytes

# %%
df.describe()
# Out:
#              age    english      maths   computer
# count   7.000000   7.000000   7.000000   7.000000
# mean   21.285714  64.142857  41.714286  37.285714
# std     1.112697  28.156873  28.715352  33.939722
# min    20.000000  23.000000   0.000000   0.000000
# 25%    20.500000  44.000000  26.500000  13.000000
# 50%    21.000000  65.000000  45.000000  25.000000
# 75%    22.000000  87.500000  54.500000  61.500000
# max    23.000000  98.000000  85.000000  87.000000

# %%
df.isnull()
# Out:
#     name    age  english  maths  computer
# 0  False  False    False  False     False
# 1  False  False    False  False     False
# 2  False  False    False  False     False
# 3  False  False    False  False     False
# 4  False  False    False  False     False
# 5  False  False    False  False     False
# 6  False  False    False  False     False
